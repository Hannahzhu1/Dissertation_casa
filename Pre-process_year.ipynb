# %% [markdown]
# # Pre-process

# %%
# Import python libraries data manipulation
import numpy as np
import pandas as pd

# %%
# Since the datafile has a Unique Key column its better to have that as the index
# Re-read datafile into df pandas dataframe setting unique key as index
df = pd.read_csv('311_Noise_Complaints.csv')
# Out:
# C:\Users\20228\AppData\Local\Temp\ipykernel_46464\2725435439.py:3: DtypeWarning: Columns (17,18,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('311_Noise_Complaints.csv')

# %%
# Setting pandas maximum colummns display so as to view all columns at once.
pd.set_option('display.max_columns', None)

# %%
# View object types of each columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5164036 entries, 0 to 5164035
# Data columns (total 39 columns):
#  #   Column                          Dtype
# ---  ------                          -----
#  0   Unique Key                      int64
#  1   Created Date                    object
#  2   Closed Date                     object
#  3   Agency                          object
#  4   Agency Name                     object
#  5   Complaint Type                  object
#  6   Descriptor                      object
#  7   Location Type                   object
#  8   Incident Zip                    float64
#  9   Incident Address                object
#  10  Street Name                     object
#  11  Cross Street 1                  object
#  12  Cross Street 2                  object
#  13  Intersection Street 1           object
#  14  Intersection Street 2           object
#  15  Address Type                    object
#  16  City                            object
# ...

# %%
df.head(3)
# Out:
#    Unique Key            Created Date             Closed Date Agency  \
# 0    52494258  11/12/2021 11:32:03 PM  11/13/2021 12:01:47 AM   NYPD
# 1    52494267  11/12/2021 10:51:56 PM  11/13/2021 02:07:21 AM   NYPD
# 2    52494269  11/12/2021 09:52:21 PM  11/12/2021 10:46:15 PM   NYPD
#
#                        Agency Name           Complaint Type        Descriptor  \
# 0  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
# 1  New York City Police Department      Noise - Residential  Loud Music/Party
# 2  New York City Police Department  Noise - Street/Sidewalk  Loud Music/Party
#
#                 Location Type  Incident Zip      Incident Address  \
# 0             Street/Sidewalk       10009.0  528 EAST   11 STREET
# 1  Residential Building/House       11385.0     1732 GROVE STREET
# 2             Street/Sidewalk       10012.0   56 MACDOUGAL STREET
#
#         Street Name  Cross Street 1 Cross Street 2 Intersection Street 1  \
# ...

# %%
# Count of non-null values for every column 
df_columns = list(df.columns)
df[df_columns].count()
# Out:
# Unique Key                        5164036
# Created Date                      5164036
# Closed Date                       5128094
# Agency                            5164036
# Agency Name                       5164036
# Complaint Type                    5164036
# Descriptor                        5164034
# Location Type                     4502854
# Incident Zip                      5151380
# Incident Address                  4767005
# Street Name                       4766971
# Cross Street 1                    4792934
# Cross Street 2                    4790107
# Intersection Street 1             2300178
# Intersection Street 2             2298234
# Address Type                      3628035
# City                              5060348
# Landmark                          1787922
# Facility Type                     2639948
# Status                            5164036
# Due Date                          2685915
# Resolution Description            5102951
# ...

# %%
noise_data = df[['Unique Key','Created Date','Closed Date','Agency','Agency Name','Descriptor','Complaint Type','Resolution Description','Resolution Action Updated Date','Incident Zip','Borough','Latitude','Longitude','Location','Address Type ']]

# %%
noise_data = noise_data.rename(columns={'Unique Key':'Unique_Key','Created Date':'Created_Date','Closed Date':'Closed_Date','Agency Name':'Agency_Name',
'Complaint Type':'Complaint_Type','Resolution Description':'Resolution_Description','Resolution Action Updated Date':'Resolution_Action_UpdatedDate',
'Incident Zip':'zipcode',
'Location':'Location'})

# %%
# separate the date
noise_data['Created_Date'] = pd.to_datetime(noise_data['Created_Date'],format='%m/%d/%Y %I:%M:%S %p')

# %%
#select date from 2019 to 2021
noise_date_19_21=noise_data[(noise_data['Created_Date'].dt.year >= 2019)&(noise_data['Created_Date'].dt.year <= 2021)]

# %%
noise_date_19_21.sort_values("Created_Date")
# Out:
#          Unique_Key        Created_Date             Closed_Date Agency  \
# 3240576    41312454 2019-01-01 00:00:29  01/01/2019 02:22:46 AM   NYPD
# 3240284    41310350 2019-01-01 00:00:43  01/01/2019 02:21:44 AM   NYPD
# 3239839    41307350 2019-01-01 00:02:13  01/02/2019 02:07:11 AM   NYPD
# 3240752    41313215 2019-01-01 00:03:08  01/01/2019 07:01:51 AM   NYPD
# 4648399    41312661 2019-01-01 00:04:26  07/29/2019 12:17:22 PM   NYPD
# ...             ...                 ...                     ...    ...
# 5142132    52938597 2021-12-31 23:59:11  01/01/2022 04:38:53 AM   NYPD
# 1688       52935775 2021-12-31 23:59:23  01/01/2022 12:40:53 AM   NYPD
# 1099       52933169 2021-12-31 23:59:36  01/01/2022 01:17:56 AM   NYPD
# 4906144    52934081 2021-12-31 23:59:38  01/01/2022 01:04:48 AM   NYPD
# 1632       52935690 2021-12-31 23:59:43  01/01/2022 12:42:07 AM   NYPD
#
#                              Agency_Name        Descriptor  \
# ...

# %%
len(noise_date_19_21)
# Out:
# 2045820

# %%
noise_date_19_21.to_csv('noise_data_zhuan.csv')
